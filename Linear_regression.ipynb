# %% [markdown]
# <a href="https://colab.research.google.com/github/vijayakrishna92/programs/blob/main/Linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/simple_linear_regression_dataset.csv")

# %%
df
# Out:
#    Hours_Studied  Exam_Score
# 0              1          52
# 1              2          56
# 2              3          61
# 3              4          63
# 4              5          67
# 5              6          72
# 6              7          74
# 7              8          79
# 8              9          83
# 9             10          88

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
x = df['Hours_Studied']
y = df['Exam_Score']

# %%
# Split data: 80% training, 20% testing
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

print("Training data:", x_train)
print("Testing data:", x_test)

# Reshape x_train and x_test to be 2D arrays
x_train = x_train.values.reshape(-1, 1)
x_test = x_test.values.reshape(-1, 1)
# Out:
# Training data: 5     6
# 0     1
# 7     8
# 2     3
# 9    10
# 4     5
# 3     4
# 6     7
# Name: Hours_Studied, dtype: int64
# Testing data: 8    9
# 1    2
# Name: Hours_Studied, dtype: int64

# %%
model = LinearRegression()
model.fit(x_train.values.reshape(-1, 1), y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test.values.reshape(-1,1))

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print("Slope (m):", model.coef_[0])
print("Intercept (b):", model.intercept_)
print("Mean Squared Error:", mse)
print("R² Score:", r2)
# Out:
# Slope (m): 3.896551724137931
# Intercept (b): 48.06896551724138
# Mean Squared Error: 0.01902497027348378
# R² Score: 0.9998956105883485

# %%
import joblib

# Save model to a file
joblib.dump(model, 'linear_regression_model.pkl')
# Out:
# ['linear_regression_model.pkl']

# %%
import joblib
import numpy as np

# Load the saved model
model = joblib.load('linear_regression_model.pkl')

# Predict exam score for new values
new_hours = np.array([[12]])  # Example: 7 hours studied
predicted_score = model.predict(new_hours)

print(f"Predicted Exam Score for 12 hours studied: {predicted_score[0]:.2f}")
# Out:
# Predicted Exam Score for 12 hours studied: 94.83
